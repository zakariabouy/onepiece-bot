# %%
# !pip install bs4
# Out:
# ...
#   Using cached bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# ...
# Using cached bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
from bs4 import BeautifulSoup

# %%
cookies = {
    'testcookie': 'supportcheck',
    'testcookie': 'supportcheck',
    '_b2': '9frfdkR43c.1740239907169',
    'fandom_global_id': 'a4ae9147-c186-404f-812b-58b8d9ff2a71',
    'wikia_beacon_id': 'rBCp4nlK5p',
    'exp_bucket': 'v6-41',
    'exp_bucket_2': 'v5-34',
    '_pubcid': '02c46397-0b9b-49bb-b1f7-81a2609ad05f',
    '_pubcid_cst': 'zix7LPQsHA%3D%3D',
    'eb': '65',
    'wikia_session_id': 'AyRRmyXMyk',
    '_cc_id': '2ef6e78bd255ae04c99560b44a90846a',
    '_scor_uid': '7c4e9fb9da0d416781afb65be072abd3',
    '__qca': 'P1-696e3578-54a6-4570-b60d-0ba9a1aa5898',
    'ac_cclang': '',
    'fan_visited_wikis': '2303899,13060,1081',
    'Geo': '{%22region%22:%2204%22%2C%22city%22:%22sale%22%2C%22country_name%22:%22morocco%22%2C%22country%22:%22MA%22%2C%22continent%22:%22AF%22}',
    '_sharedid': '6c57f36e-3ba5-4511-b9b9-a97eab3bbc7e',
    '_sharedid_cst': 'zix7LPQsHA%3D%3D',
    '_lr_env_src_ats': 'false',
    'cebs': '1',
    '__bm_m': '',
    '_ce.clock_data': '241%2C196.74.202.205%2C1%2C3c9fc7ddec9b58823c1c96756dbd45d8%2CChrome%2CMA',
    'idw-fe-id': 'c3499bc3-bd98-49f2-b54f-829f6167b560',
    '_lr_sampling_rate': '100',
    'active_cms_notification': '-1',
    'sessionId': '4f4d6057-8208-4cab-aa86-34b104dd1a29',
    '_lr_retry_request': 'true',
    'leftPanelOpen': '0',
    'AMP_MKTG_6765a55f49': 'JTdCJTdE',
    '__gads': 'ID=bfb112d0ed74f52f:T=1758045266:RT=1763826082:S=ALNI_MaVSRVo14FrjDqwRjswmOsLA4XCkQ',
    '__gpi': 'UID=0000128d12734524:T=1758045266:RT=1763826082:S=ALNI_MYMb1VaBSp7EBn_PPiUVwTfqLCdbQ',
    '__eoi': 'ID=32df41e021e27216:T=1758045266:RT=1763826082:S=AA-AfjYyWbbEJ0wU31Nd2B78TnGk',
    '_fs_cd_cp_pRdRgnTnF68pCV2F': 'ASSONrvXLtgctDhAN2xYfUvin8F1_AJBYZrm1qSnQJRD5DGb9ovaqmloPcf9xyKoIgrRR5rTF4xNqfpErCSNbGfHUbrkkNCVHtfKixu-cLTfK2p79jd3GkZ5g8C0GN-O2tiTpmnz4ztXnx_8m6zaXv_BbQY=',
1.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=765d10ec-7ea1-47db-b420-83fbd531cf04&interactionCount=1&isAnonUser=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A1%2CC0003%3A1%2CC0004%3A1%2CC0005%3A1&AwaitingReconsent=false&geolocation=MA%3B06; OptanonAlertBoxClosed=2025-11-22T15:45:53.744Z; cto_bundle=qE_lU19TRHkyR2lWemlvdFgyelZEZ09lc1IyVVp1MlVBcXNiM3gxRyUyQmk3NWZDaUNkMzQ1RWtXUXZMOEdrSDJqMXg4bCUyQlBWMGUzOGxMQUpWT1k4c1B3VXRuJTJCV0hWSXl6OXNBeW5mVTIlMkJYYjhKTmRRJTJCTHhkOG12T1U1ZUVibU9qVTFhbzQ1YnNOTnl0bmYlMkJQeVhtTk5OakdaamclM0QlM0Q; cto_bidid=XnUxmF9oOWg4RkRGRGpiR0JmWklxVTgzTTVpcnJyM04lMkZrWHFBZTFabFp4NCUyRk1DVHZyd3BIRE5SdW0yY3RGVXE3dGRTOHJNQmJ2TlJ4TktlbEVuVVJ6bDVON0o1TlJUOGVrb1cxY1VZMDVaU2VFMEElM0Q; FCNEC=%5B%5B%22AKsRol-mAFO6ljD0rPamaIlX1JLmeYHYoIuhZCvCPb_cD_j2VzIc9GphnfQAozRkjGu7fx54YhUssQtoK8ZiV7nrlly1i4HZ4vSonqu5S1dr5v__dkNZEYDXdjEqvgpvESL84_vK5mx4ZO1QPWnCb2uXJkkBqKYQ_w%3D%3D%22%5D%5D; nol_fpid=s2lcs4n08xjivxnphgggrqzaudzx91758045266|1758045266320|1763826354051|1763826354089; AMP_6765a55f49=JTdCJTIyZGV2aWNlSWQlMjIlM0ElMjIzNTM2NzViZC1lZjBlLTQ3N2EtYWJjYy1hOTdkOTkwOWZmMTclMjIlMkMlMjJzZXNzaW9uSWQlMjIlM0ExNzYzODIzMzk0NjMxJTJDJTIyb3B0T3V0JTIyJTNBZmFsc2UlMkMlMjJsYXN0RXZlbnRUaW1lJTIyJTNBMTc2MzgyNjM1MzQ4MyUyQyUyMmxhc3RFdmVudElkJTIyJTNBNjElN0Q=; cebsp_=8',
}

# %%
req_url = 'https://onepiece.fandom.com/fr/wiki/Chapitres_et_Tomes/Tomes_%s_à_%s'

# %%
def get_page_content(start: int, end: int) -> str:
    url = req_url % (start, end)
    response = requests.get(
        url,
        cookies=cookies,
        headers=headers,
    )
    return response.text

# %%
content = get_page_content(1, 10)

# %%
soup = BeautifulSoup(content, 'html.parser')

# %%
chapitre_url = "https://onepiece.fandom.com/fr/wiki/Chapitre_%s"

# %%
def get_chapitre_content(chapitre_number: int) -> str:
    url = chapitre_url % chapitre_number   
    response = requests.get(
        url,
        cookies=cookies,
        headers=headers,
    )
    return response.text

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs sse-dplat-1831-rejected sse-other l2u-other" dir="ltr" lang="fr">
# <head>
# <meta charset="utf-8"/>
# <title>Tomes 1 à 10 | One Piece Encyclopédie | Fandom</title>
# ...

# %%
content = get_chapitre_content(1)

# %%
def parse_chapitre(content: str):
    soup = BeautifulSoup(content, 'html.parser')
    #TODO: parse content
    
    return {
        
    }

# %%
parse_chapitre(content)
