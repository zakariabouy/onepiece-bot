# %%
import sqlite3

conn = sqlite3.connect("data/db/onepiece.db")
rows = conn.execute("SELECT id, title, arc, text FROM notes LIMIT 5").fetchall()
conn.close()

for r in rows:
    print(r[0], r[1], r[2])
    print(r[3][:200], "\n")
# Out:
# yonko_concept Who are the Yonko? General Lore
# Yonko are top pirate captains who dominate the seas; membership has changed over time after major events.
#
# wano_themes Wano themes Wano
# An alliance challenges tyranny; liberation themes and long-running threads conclude, changing regional influence.
#
# ace Portgas D. Ace Marineford
# Ace is Luffy’s sworn brother and a commander in Whitebeard’s crew. He ate the Mera Mera no Mi, gaining fire-based powers.
#
# shichibukai Shichibukai General Lore
# The Shichibukai were seven powerful pirates allied with the World Government. They were allowed to continue pirating in exchange for serving the Marines when needed. The system was later abolished due
#
# luffy_intro Monkey D. Luffy East Blue
# Monkey D. Luffy is the captain of the Straw Hat Pirates. He aims to become the Pirate King by finding the One Piece. After eating the Gum-Gum Fruit he fights with rubber-like stretching techniques.
